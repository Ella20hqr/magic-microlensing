# %%
import numpy as np
import pandas as pd
import os
eventname = 'KB182758'
obs = ['KMTA02', 'KMTA42', 'KMTC02', 'KMTC42', 'KMTS02', 'KMTS42']
path = './%s'%(eventname)

# %%
files = os.listdir(path)
data = [np.loadtxt(os.path.join(path, x)) for x in files]
print(data)

# kmta01 = np.loadtxt('KB-18-0800-kmta01.dat')
# kmta42 = np.loadtxt('KB-18-0800-kmta42.dat')
# kmtc01 = np.loadtxt('KB-18-0800-kmtc01.dat')
# kmtc42 = np.loadtxt('KB-18-0800-kmtc42.dat')
# kmts01 = np.loadtxt('KB-18-0800-kmts01.dat')
# kmts42 = np.loadtxt('KB-18-0800-kmts42.dat')
# data = [kmta01, kmta42, kmtc01, kmtc42, kmts01, kmts42]

# Tel,Filter,HJD,mag,e_mag,mag_aligned,e_mag_aligned
# date,modmag,imag,imerr
# Out:
# [array([[8.17124046e+03, 1.71566580e+01, 1.71235590e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.17125212e+03, 1.71566580e+01, 1.71418790e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.17126425e+03, 1.71566580e+01, 1.71205920e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        ...,
#        [8.40692365e+03, 1.71070720e+01, 1.70979840e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.40693724e+03, 1.71071030e+01, 1.70779430e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.40694708e+03, 1.71071260e+01, 1.70588290e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00]]), array([[8.16885695e+03, 1.71566600e+01, 1.71897000e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.17086529e+03, 1.71566580e+01, 1.71320000e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.17088850e+03, 1.71566580e+01, 1.72033000e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        ...,
#        [8.41251418e+03, 1.71194410e+01, 1.71029000e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.41253082e+03, 1.71194750e+01, 1.70976000e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.41254081e+03, 1.71194950e+01, 1.71478000e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00]]), array([[8.17257724e+03, 1.71566560e+01, 1.71345400e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.17259639e+03, 1.71566560e+01, 1.71553510e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.17260822e+03, 1.71566560e+01, 1.71466470e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        ...,
#        [8.40726300e+03, 1.71078500e+01, 1.70486230e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.40728725e+03, 1.71079060e+01, 1.69336700e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.40729742e+03, 1.71079290e+01, 1.71832120e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00]]), array([[8.16887276e+03, 1.71566600e+01, 1.71424310e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.16887484e+03, 1.71566600e+01, 1.71481680e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.16888455e+03, 1.71566600e+01, 1.71712160e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        ...,
#        [8.41250560e+03, 1.71194240e+01, 1.71193870e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.41252637e+03, 1.71194660e+01, 1.71008730e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.41253667e+03, 1.71194870e+01, 1.71032870e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00]]), array([[8.17259047e+03, 1.71566560e+01, 1.71511080e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.17260236e+03, 1.71566560e+01, 1.71525420e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.17261423e+03, 1.71566560e+01, 1.71485580e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        ...,
#        [8.40726898e+03, 1.71078640e+01, 1.71302650e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.40728097e+03, 1.71078910e+01, 1.71081150e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.40729291e+03, 1.71079190e+01, 1.70158870e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00]]), array([[8.17123463e+03, 1.71566580e+01, 1.71203800e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.17124613e+03, 1.71566580e+01, 1.71366210e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.17125767e+03, 1.71566580e+01, 1.71675510e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        ...,
#        [8.40691791e+03, 1.71070590e+01, 1.71239330e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.40692916e+03, 1.71070850e+01, 1.70847090e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00],
#        [8.40694275e+03, 1.71071160e+01, 1.71888080e+01, ...,
#         0.00000000e+00, 1.03418000e+00, 0.00000000e+00]])]

# %%
Tel = np.hstack([np.full((1, len(ob)), obs[i]) for i,ob in enumerate(data)])[0]
Filter = np.full((sum(len(x) for x in data)), 'I')
HJD = np.hstack([ob[:, 0] for ob in data])
mag_aligned = np.hstack([ob[:, 2] for ob in data])
e_mag_aligned = np.hstack([ob[:, 3] for ob in data])
mag = np.zeros((sum(len(x) for x in data)))
e_mag = np.zeros((sum(len(x) for x in data)))

# %%
data_aligned = pd.DataFrame({'Tel':Tel, 'Filter':Filter, 'HJD':HJD, 'mag':mag, 'e_mag':e_mag, 'mag_aligned':mag_aligned, 'e_mag_aligned':e_mag_aligned})
data_aligned.to_csv('./%s/%s_aligned.csv'%(eventname, eventname), index=False, sep=',')
